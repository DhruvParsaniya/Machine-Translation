# %%
import torch
import torch.nn as nn
from torch import optim
from torch.utils.data import Dataset, DataLoader, random_split

from io import open
import unicodedata
import re

# %%
if torch.cuda.is_available():
    device=torch.device(type='cuda', index=0)
else:
    device=torch.device(type='cpu', index=0)

# %%
#unicode 2 ascii, remove non-letter characters, trim
def normalizeString(s): 
    sres=""
    for ch in unicodedata.normalize('NFD', s): 
        #Return the normal form form ('NFD') for the Unicode string s.
        if unicodedata.category(ch) != 'Mn':
            # The function in the first part returns the general 
            # category assigned to the character ch as string. 
            # "Mn' refers to Mark, Nonspacing
            sres+=ch
    sres = re.sub(r"([.!?])", r" \1", sres) 
    # inserts a space before any occurrence of ".", "!", or "?" in the string sres. 
    sres = re.sub(r"[^a-zA-Z!?]+", r" ", sres) 
    # this line of code replaces any sequence of characters in sres 
    # that are not letters (a-z or A-Z) or the punctuation marks 
    # "!" or "?" with a single space character.
    return sres.strip()

#create list of pairs (list of lists) (no filtering)
def createNormalizedPairs():
    initpairs=[]
    for pair in data:
        s1,s2=pair.split('\t')
        s1=normalizeString(s1.lower().strip())
        s2=normalizeString(s2.lower().strip())
        initpairs.append([s1,s2])
    #print(len(initpairs))
    return initpairs

#filter pairs
max_length = 10
def filterPairs(initpairs):
    #filtering conditions in addition to max_length
    eng_prefixes = (
        "i am ", "i m ",
        "he is", "he s ",
        "she is", "she s ",
        "you are", "you re ",
        "we are", "we re ",
        "they are", "they re "
    )

    pairs=[]
    for pair in initpairs:
        if len(pair[0].split(" ")) < max_length and len(pair[1].split(" ")) < max_length and pair[0].lower().startswith(eng_prefixes):
            pairs.append(pair)

    print("Number of pairs after filtering:", len(pairs))
    return pairs

# %%
class Vocab:
    def __init__(self, name):
        self.name=name
        self.word2index={'SOS':0, 'EOS':1}
        self.index2word={0:'SOS', 1:'EOS'}
        self.word2count={}
        self.nwords=2
    
    def buildVocab(self,s):
        for word in s.split(" "):
            if word not in self.word2index:
                self.word2index[word]=self.nwords
                self.index2word[self.nwords]=word
                self.word2count[word]=1
                self.nwords+=1
            else:
                self.word2count[word]+=1

# %%
class Encoder(nn.Module):
    def __init__(self, input_size, embed_size, hidden_size, dropout_p=0.1):
        super().__init__()
        self.e=nn.Embedding(input_size, embed_size)
        self.dropout=nn.Dropout(dropout_p)
        self.gru=nn.GRU(embed_size,hidden_size, batch_first=True)
    
    def forward(self,x):
        x=self.e(x)
        x=self.dropout(x)
        outputs, hidden=self.gru(x)
        return outputs, hidden

# %%
class Decoder(nn.Module):
    def __init__(self,output_size,embed_size,hidden_size):
        super().__init__()
        self.e=nn.Embedding(output_size,embed_size)
        self.relu=nn.ReLU()
        self.gru=nn.GRU(embed_size, hidden_size, batch_first=True)
        self.lin=nn.Linear(hidden_size,output_size)
        self.lsoftmax=nn.LogSoftmax(dim=-1)
    
    def forward(self,x,prev_hidden):
        x=self.e(x)
        x=self.relu(x)
        output,hidden=self.gru(x,prev_hidden)
        y=self.lin(output)
        y=self.lsoftmax(y)
        return y, hidden

# %%
def get_input_ids(sentence,langobj):
    input_ids=[]
    for word in sentence.split(" "):
        input_ids.append(langobj.word2index[word])
    
    if langobj.name=='fre': #translation-direction sensitive
        input_ids.append(langobj.word2index['EOS'])
    else:
        input_ids.insert(0,langobj.word2index['SOS'])
        input_ids.append(langobj.word2index['EOS'])
    return torch.tensor(input_ids)

# %%
class CustomDataset(Dataset):
    def __init__(self):
        super().__init__()
    
    def __len__(self):
        return length
    
    def __getitem__(self,idx):
        t=pairs[idx][0] #translation-direction sensitive
        s=pairs[idx][1] #translation-direction sensitive
        s_input_ids=torch.zeros(max_length+1, dtype=torch.int64)
        t_input_ids=torch.zeros(max_length+2, dtype=torch.int64)
        s_input_ids[:len(s.split(" "))+1]=get_input_ids(s,fre) #translation-direction sensitive
        t_input_ids[:len(t.split(" "))+2]=get_input_ids(t,eng) #translation-direction sensitive
        
        return s_input_ids, t_input_ids

# %%
def train_one_epoch():
    encoder.train()
    decoder.train()
    track_loss=0
    
    for i, (s_ids,t_ids) in enumerate(train_dataloader):
        s_ids=s_ids.to(device)
        t_ids=t_ids.to(device)
        encoder_outputs, encoder_hidden=encoder(s_ids)
        decoder_hidden=encoder_hidden
        yhats, decoder_hidden = decoder(t_ids[:,0:-1],decoder_hidden)
                    
        gt=t_ids[:,1:]
        
        yhats_reshaped=yhats.view(-1,yhats.shape[-1])
        
        gt=gt.reshape(-1)
        
        
        loss=loss_fn(yhats_reshaped,gt)
        track_loss+=loss.item()
        
        opte.zero_grad()
        optd.zero_grad()
        
        loss.backward()
        
        opte.step()
        optd.step()
        
    return track_loss/len(train_dataloader)

# %%
def ids2Sentence(ids,vocab):
    sentence=""
    for id in ids.squeeze():
        if id==0:
            continue
        word=vocab.index2word[id.item()]
        sentence+=word + " "
        if id==1:  
            break
    return sentence

# %%
#eval loop (written assuming batch_size=1)
def eval_one_epoch(e,n_epochs):
    encoder.eval()
    decoder.eval()
    track_loss=0
    with torch.no_grad():
        for i, (s_ids,t_ids) in enumerate(test_dataloader):
            s_ids=s_ids.to(device)
            t_ids=t_ids.to(device)
            encoder_outputs, encoder_hidden=encoder(s_ids)
            decoder_hidden=encoder_hidden #n_dim=3
            input_ids=t_ids[:,0]
            yhats=[]
            if e+1==n_epochs:
                pred_sentence=""
            for j in range(1,max_length+2): #j starts from 1
                probs, decoder_hidden = decoder(input_ids.unsqueeze(1),decoder_hidden)
                yhats.append(probs)
                _,input_ids=torch.topk(probs,1,dim=-1)
                input_ids=input_ids.squeeze(1,2) #still a tensor
                if e+1==n_epochs:
                    word=eng.index2word[input_ids.item()] #batch_size=1
                    pred_sentence+=word + " "
                if input_ids.item() == 1: #batch_size=1
                    break
                                
            if e+1==n_epochs:
                src_sentence=ids2Sentence(s_ids,fre) #translation-direction sensitive
                gt_sentence=ids2Sentence(t_ids[:,1:],eng) #translation-direction sensitive

                print("\n-----------------------------------")
                print("Source Sentence:",src_sentence)
                print("GT Sentence:",gt_sentence)
                print("Predicted Sentence:",pred_sentence)
            
            yhats_cat=torch.cat(yhats,dim=1)
            yhats_reshaped=yhats_cat.view(-1,yhats_cat.shape[-1])
            gt=t_ids[:,1:j+1]
            gt=gt.view(-1)
            

            loss=loss_fn(yhats_reshaped,gt)
            track_loss+=loss.item()
            
        if e+1==n_epochs:    
            print("-----------------------------------")
        return track_loss/len(test_dataloader)

# %%
#driver code

#read data
data=open("/kaggle/input/eng-fre-trans/eng-fra.txt").read().strip().split('\n')
print("Total number of pairs:",len(data))

#create pairs (create + normalize)
initpairs=createNormalizedPairs() #list of lists. Each inner list is a pair

#filter pairs
pairs=filterPairs(initpairs)
length=len(pairs)

#create Vocab objects for each language
eng=Vocab('eng')
fre=Vocab('fre')

#build the vocab
for pair in pairs:
    eng.buildVocab(pair[0])
    fre.buildVocab(pair[1])

#print vocab size
print("English Vocab Length:",eng.nwords)
print("French Vocab Length:",fre.nwords)    
    
dataset=CustomDataset()
train_dataset,test_dataset=random_split(dataset,[0.99,0.01])

batch_size=32
train_dataloader=DataLoader(dataset=train_dataset,batch_size=batch_size, shuffle=False)
test_dataloader=DataLoader(dataset=test_dataset,batch_size=1, shuffle=False)

    
embed_size=300
hidden_size=512

encoder=Encoder(fre.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive
decoder=Decoder(eng.nwords,embed_size,hidden_size).to(device) #translation-direction sensitive

loss_fn=nn.NLLLoss(ignore_index=0).to(device)
lr=0.001
opte=optim.Adam(params=encoder.parameters(), lr=lr, weight_decay=0.001)
optd=optim.Adam(params=decoder.parameters(), lr=lr, weight_decay=0.001)

n_epochs=80

for e in range(n_epochs):
    print("Epoch=",e+1, sep="", end=", ")
    print("Train Loss=", round(train_one_epoch(),4), sep="", end=", ")
    print("Eval Loss=",round(eval_one_epoch(e,n_epochs),4), sep="")
# Out:
# Total number of pairs: 135842
# Number of pairs after filtering: 11445
# English Vocab Length: 2991
# French Vocab Length: 4601
# Epoch=1, Train Loss=3.1498, Eval Loss=3.3766
# Epoch=2, Train Loss=2.4137, Eval Loss=3.1472
# Epoch=3, Train Loss=2.1787, Eval Loss=2.9177
# Epoch=4, Train Loss=2.0527, Eval Loss=2.7982
# Epoch=5, Train Loss=1.9814, Eval Loss=2.6393
# Epoch=6, Train Loss=1.9324, Eval Loss=2.549
# Epoch=7, Train Loss=1.8874, Eval Loss=2.5662
# Epoch=8, Train Loss=1.842, Eval Loss=2.5203
# Epoch=9, Train Loss=1.7934, Eval Loss=2.4571
# Epoch=10, Train Loss=1.7474, Eval Loss=2.3836
# Epoch=11, Train Loss=1.7079, Eval Loss=2.4303
# Epoch=12, Train Loss=1.6659, Eval Loss=2.3827
# Epoch=13, Train Loss=1.6279, Eval Loss=2.518
# Epoch=14, Train Loss=1.5907, Eval Loss=2.2871
# Epoch=15, Train Loss=1.5633, Eval Loss=2.2281
# Epoch=16, Train Loss=1.5322, Eval Loss=2.2269
# Epoch=17, Train Loss=1.5078, Eval Loss=2.2466
# Epoch=18, Train Loss=1.486, Eval Loss=2.193
# Epoch=19, Train Loss=1.4643, Eval Loss=2.1774
# Epoch=20, Train Loss=1.449, Eval Loss=2.1389
# Epoch=21, Train Loss=1.4227, Eval Loss=2.1486
# Epoch=22, Train Loss=1.4048, Eval Loss=2.2391
# Epoch=23, Train Loss=1.3925, Eval Loss=2.085
# Epoch=24, Train Loss=1.3796, Eval Loss=2.1408
# Epoch=25, Train Loss=1.3648, Eval Loss=2.2423
# Epoch=26, Train Loss=1.3475, Eval Loss=2.1418
# Epoch=27, Train Loss=1.3418, Eval Loss=2.0732
# Epoch=28, Train Loss=1.3355, Eval Loss=2.1616
# Epoch=29, Train Loss=1.3239, Eval Loss=2.1069
# Epoch=30, Train Loss=1.3176, Eval Loss=2.0505
# Epoch=31, Train Loss=1.3067, Eval Loss=2.1515
# Epoch=32, Train Loss=1.3039, Eval Loss=2.1575
# Epoch=33, Train Loss=1.2956, Eval Loss=2.2318
# Epoch=34, Train Loss=1.2849, Eval Loss=2.0877
# Epoch=35, Train Loss=1.2811, Eval Loss=2.1748
# Epoch=36, Train Loss=1.2786, Eval Loss=2.0211
# Epoch=37, Train Loss=1.2663, Eval Loss=2.1209
# Epoch=38, Train Loss=1.2698, Eval Loss=2.0995
# Epoch=39, Train Loss=1.2686, Eval Loss=2.0692
# Epoch=40, Train Loss=1.2581, Eval Loss=2.0792
# Epoch=41, Train Loss=1.2483, Eval Loss=2.0766
# Epoch=42, Train Loss=1.2455, Eval Loss=1.9972
# Epoch=43, Train Loss=1.2517, Eval Loss=2.0198
# Epoch=44, Train Loss=1.2485, Eval Loss=2.0011
# Epoch=45, Train Loss=1.237, Eval Loss=2.0405
# Epoch=46, Train Loss=1.2315, Eval Loss=2.1939
# Epoch=47, Train Loss=1.2351, Eval Loss=2.1088
# Epoch=48, Train Loss=1.2318, Eval Loss=2.135
# Epoch=49, Train Loss=1.2222, Eval Loss=2.0036
# Epoch=50, Train Loss=1.2214, Eval Loss=2.0409
# Epoch=51, Train Loss=1.2196, Eval Loss=2.0174
# Epoch=52, Train Loss=1.2217, Eval Loss=1.9964
# Epoch=53, Train Loss=1.2212, Eval Loss=2.0292
# Epoch=54, Train Loss=1.2169, Eval Loss=1.9903
# Epoch=55, Train Loss=1.2119, Eval Loss=1.9997
# Epoch=56, Train Loss=1.2089, Eval Loss=2.025
# Epoch=57, Train Loss=1.205, Eval Loss=2.1582
# Epoch=58, Train Loss=1.209, Eval Loss=2.1018
# Epoch=59, Train Loss=1.2088, Eval Loss=1.9684
# Epoch=60, Train Loss=1.1985, Eval Loss=2.0422
# Epoch=61, Train Loss=1.2006, Eval Loss=2.0402
# Epoch=62, Train Loss=1.203, Eval Loss=1.9893
# Epoch=63, Train Loss=1.1971, Eval Loss=1.9763
# Epoch=64, Train Loss=1.1976, Eval Loss=1.9988
# Epoch=65, Train Loss=1.192, Eval Loss=2.0045
# Epoch=66, Train Loss=1.1906, Eval Loss=2.0804
# Epoch=67, Train Loss=1.1944, Eval Loss=1.91
# Epoch=68, Train Loss=1.1935, Eval Loss=1.9806
# Epoch=69, Train Loss=1.188, Eval Loss=2.0598
# Epoch=70, Train Loss=1.1847, Eval Loss=2.0192
# Epoch=71, Train Loss=1.1881, Eval Loss=1.9489
# Epoch=72, Train Loss=1.1869, Eval Loss=1.9704
# Epoch=73, Train Loss=1.1852, Eval Loss=2.0413
# Epoch=74, Train Loss=1.18, Eval Loss=1.8567
# Epoch=75, Train Loss=1.1811, Eval Loss=1.9953
# Epoch=76, Train Loss=1.1784, Eval Loss=2.1816
# Epoch=77, Train Loss=1.1868, Eval Loss=2.0417
# Epoch=78, Train Loss=1.1793, Eval Loss=1.8813
# Epoch=79, Train Loss=1.1805, Eval Loss=1.9346
# Epoch=80, Train Loss=1.1712,
# -----------------------------------
# Source Sentence: vous etes tres timides EOS
# GT Sentence: you re very timid EOS
# Predicted Sentence: you re very timid EOS
#
# -----------------------------------
# Source Sentence: je suis dans le petrin EOS
# GT Sentence: i am in trouble EOS
# Predicted Sentence: i m in trouble with a hot EOS
#
# -----------------------------------
# Source Sentence: vous etes tellement impatiente EOS
# GT Sentence: you re so impatient EOS
# Predicted Sentence: you re so impatient EOS
#
# -----------------------------------
# Source Sentence: je ne demens pas cela EOS
# GT Sentence: i m not denying that EOS
# Predicted Sentence: i m not thinking this EOS
#
# -----------------------------------
# Source Sentence: je cherche ma cle EOS
# GT Sentence: i m looking for my key EOS
# Predicted Sentence: i m looking for my old EOS
#
# -----------------------------------
# Source Sentence: elles sont toutes terrifiees EOS
# GT Sentence: they re all terrified EOS
# Predicted Sentence: they re all gone EOS
#
# -----------------------------------
# Source Sentence: je suis ici pour faire ce que je peux EOS
# GT Sentence: i m here to do what i can EOS
# Predicted Sentence: i m being paid to do this here EOS
#
# -----------------------------------
# Source Sentence: nous sommes plutot occupees ici EOS
# GT Sentence: we re kind of busy here EOS
# Predicted Sentence: we re too busy EOS
#
# -----------------------------------
# Source Sentence: tu es tres genereuse EOS
# GT Sentence: you re very generous EOS
# Predicted Sentence: you re very generous EOS
#
# -----------------------------------
# Source Sentence: je suis sur le chemin de la maison EOS
# GT Sentence: i m on the way home EOS
# Predicted Sentence: i m on on the house in the house EOS
#
# -----------------------------------
# Source Sentence: ca ne me fait pas peur EOS
# GT Sentence: i m not scared EOS
# Predicted Sentence: i m not afraid of it EOS
#
# -----------------------------------
# Source Sentence: je suis un moine EOS
# GT Sentence: i am a monk EOS
# Predicted Sentence: i m a traitor EOS
#
# -----------------------------------
# Source Sentence: nous allons travailler ce soir EOS
# GT Sentence: we re going to work tonight EOS
# Predicted Sentence: we re going to play on the ship EOS
#
# -----------------------------------
# Source Sentence: tu es chanceuse d avoir un travail EOS
# GT Sentence: you re lucky that you have a job EOS
# Predicted Sentence: you re going to have a father EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas sur d y etre pret EOS
# GT Sentence: i m not sure i m ready for this EOS
# Predicted Sentence: i m not sure to go about this EOS
#
# -----------------------------------
# Source Sentence: je vais epargner plus d argent EOS
# GT Sentence: i m going to save more money EOS
# Predicted Sentence: i m going of money money EOS
#
# -----------------------------------
# Source Sentence: nous sommes enseignants EOS
# GT Sentence: we are teachers EOS
# Predicted Sentence: we re a same world EOS
#
# -----------------------------------
# Source Sentence: ils sont tous decedes EOS
# GT Sentence: they re all dead EOS
# Predicted Sentence: they re all dead EOS
#
# -----------------------------------
# Source Sentence: elle est certaine de venir a temps EOS
# GT Sentence: she is certain to come on time EOS
# Predicted Sentence: she is sure about the success EOS
#
# -----------------------------------
# Source Sentence: c est un critique acerbe EOS
# GT Sentence: he is a harsh critic EOS
# Predicted Sentence: he s a big naive EOS
#
# -----------------------------------
# Source Sentence: je suis sur de son succes EOS
# GT Sentence: i am sure of her success EOS
# Predicted Sentence: i am sure of his success EOS
#
# -----------------------------------
# Source Sentence: je suis faineant EOS
# GT Sentence: i am lazy EOS
# Predicted Sentence: i m lazy EOS
#
# -----------------------------------
# Source Sentence: je vaux mieux que ca EOS
# GT Sentence: i m worth more than this EOS
# Predicted Sentence: i m better better EOS
#
# -----------------------------------
# Source Sentence: je crains que tu m aies mal compris EOS
# GT Sentence: i m afraid you misunderstood me EOS
# Predicted Sentence: i m afraid you ve it the ve EOS
#
# -----------------------------------
# Source Sentence: elles sont onereuses EOS
# GT Sentence: they re expensive EOS
# Predicted Sentence: they re eating EOS
#
# -----------------------------------
# Source Sentence: c est bon pour moi EOS
# GT Sentence: i m fine with it EOS
# Predicted Sentence: i m good old to him EOS
#
# -----------------------------------
# Source Sentence: vous etes le plus vieux EOS
# GT Sentence: you re the oldest EOS
# Predicted Sentence: you re the oldest EOS
#
# -----------------------------------
# Source Sentence: je n en suis pas si sure ! EOS
# GT Sentence: i m not so sure EOS
# Predicted Sentence: i m not sure sure EOS
#
# -----------------------------------
# Source Sentence: je suis fier de le tenir pour ami EOS
# GT Sentence: i m proud to have him as a friend EOS
# Predicted Sentence: i m proud to do you as a friend EOS
#
# -----------------------------------
# Source Sentence: je commets trop de fautes EOS
# GT Sentence: i am making too many mistakes EOS
# Predicted Sentence: i m too too time to money EOS
#
# -----------------------------------
# Source Sentence: nous sommes fermes le lundi EOS
# GT Sentence: we re closed on mondays EOS
# Predicted Sentence: we re on the ship EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas si pressee EOS
# GT Sentence: i m not in that much of a hurry EOS
# Predicted Sentence: i m not so that of this anymore EOS
#
# -----------------------------------
# Source Sentence: tu es le plus grand EOS
# GT Sentence: you are tallest EOS
# Predicted Sentence: you re the oldest EOS
#
# -----------------------------------
# Source Sentence: je ne suis plus tout jeune EOS
# GT Sentence: i m not young anymore EOS
# Predicted Sentence: i m not young anymore EOS
#
# -----------------------------------
# Source Sentence: vous n etes plus les bienvenus ici EOS
# GT Sentence: you are no longer welcome here EOS
# Predicted Sentence: you re not longer here here EOS
#
# -----------------------------------
# Source Sentence: tu es prevenante EOS
# GT Sentence: you re considerate EOS
# Predicted Sentence: you re charming EOS
#
# -----------------------------------
# Source Sentence: je me rejouis de vous revoir bientot EOS
# GT Sentence: i am looking forward to seeing you again soon EOS
# Predicted Sentence: i m glad to see you again EOS
#
# -----------------------------------
# Source Sentence: je suis facile a vivre EOS
# GT Sentence: i m easygoing EOS
# Predicted Sentence: i m tough EOS
#
# -----------------------------------
# Source Sentence: je suis creve EOS
# GT Sentence: i am tired EOS
# Predicted Sentence: i m exhausted EOS
#
# -----------------------------------
# Source Sentence: t es pas aussi maligne que moi EOS
# GT Sentence: you re not as smart as me EOS
# Predicted Sentence: you re not as smart as me EOS
#
# -----------------------------------
# Source Sentence: je suis tres occupe aujourd hui EOS
# GT Sentence: i m very busy today EOS
# Predicted Sentence: i m not busy today EOS
#
# -----------------------------------
# Source Sentence: je songe au projet EOS
# GT Sentence: i m thinking of the plan EOS
# Predicted Sentence: i m thinking resigning my money EOS
#
# -----------------------------------
# Source Sentence: je suis tres stricte EOS
# GT Sentence: i m very strict EOS
# Predicted Sentence: i m very astute EOS
#
# -----------------------------------
# Source Sentence: tu es tout pour moi EOS
# GT Sentence: you are everything to me EOS
# Predicted Sentence: you re listening to me EOS
#
# -----------------------------------
# Source Sentence: il a decide de quitter la troupe EOS
# GT Sentence: he s decided to leave the company EOS
# Predicted Sentence: he is on the hard the the ship EOS
#
# -----------------------------------
# Source Sentence: je conduis EOS
# GT Sentence: i m driving EOS
# Predicted Sentence: i m thinking EOS
#
# -----------------------------------
# Source Sentence: il n est pas marie EOS
# GT Sentence: he is not married EOS
# Predicted Sentence: he is not married EOS
#
# -----------------------------------
# Source Sentence: j ai toujours faim EOS
# GT Sentence: i m always hungry EOS
# Predicted Sentence: i m still hungry EOS
#
# -----------------------------------
# Source Sentence: tu es en avance EOS
# GT Sentence: you are early EOS
# Predicted Sentence: you re early EOS
#
# -----------------------------------
# Source Sentence: je suis tellement deborde EOS
# GT Sentence: i m so overworked EOS
# Predicted Sentence: i m so so embarrassed EOS
#
# -----------------------------------
# Source Sentence: je suis accro EOS
# GT Sentence: i m addicted EOS
# Predicted Sentence: i m a heroin EOS
#
# -----------------------------------
# Source Sentence: il se trouve a son cote EOS
# GT Sentence: he s at her side EOS
# Predicted Sentence: he is at his at him EOS
#
# -----------------------------------
# Source Sentence: c est une connaissance de ma femme EOS
# GT Sentence: he is acquainted with my wife EOS
# Predicted Sentence: she is my wife with my wife EOS
#
# -----------------------------------
# Source Sentence: je te donne une occasion EOS
# GT Sentence: i m giving you an opportunity EOS
# Predicted Sentence: i m giving you give a chance EOS
#
# -----------------------------------
# Source Sentence: je prends mon apres midi demain EOS
# GT Sentence: i m taking tomorrow afternoon off EOS
# Predicted Sentence: i am going on the next tomorrow EOS
#
# -----------------------------------
# Source Sentence: vous etes extraverti EOS
# GT Sentence: you re extroverted EOS
# Predicted Sentence: you re outgoing EOS
#
# -----------------------------------
# Source Sentence: t es bourre EOS
# GT Sentence: you re smashed EOS
# Predicted Sentence: you re drunk EOS
#
# -----------------------------------
# Source Sentence: vous n etes pas seule EOS
# GT Sentence: you re not alone EOS
# Predicted Sentence: you re not alone alone EOS
#
# -----------------------------------
# Source Sentence: nous faisons toutes partie de la meme equipe EOS
# GT Sentence: we re all on the same team EOS
# Predicted Sentence: we re all in the same of our team EOS
#
# -----------------------------------
# Source Sentence: je suis desolee mon pere n est pas la EOS
# GT Sentence: i m sorry my father s not here EOS
# Predicted Sentence: i m sorry my not is not a teacher EOS
#
# -----------------------------------
# Source Sentence: elle a divorce EOS
# GT Sentence: she s divorced EOS
# Predicted Sentence: she is done with her EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas fatigue du tout EOS
# GT Sentence: i m not at all tired EOS
# Predicted Sentence: i m not tired at all EOS
#
# -----------------------------------
# Source Sentence: nous sommes en train de mediter EOS
# GT Sentence: we re meditating EOS
# Predicted Sentence: we re stalling EOS
#
# -----------------------------------
# Source Sentence: ils sont juste derriere moi EOS
# GT Sentence: they re right behind me EOS
# Predicted Sentence: they re right behind me EOS
#
# -----------------------------------
# Source Sentence: je suis desole de vous avoir derangee ! EOS
# GT Sentence: i m sorry to have bothered you EOS
# Predicted Sentence: i m sorry to have disturbed you EOS
#
# -----------------------------------
# Source Sentence: vous etes tres ouvert EOS
# GT Sentence: you re very open EOS
# Predicted Sentence: you re very open EOS
#
# -----------------------------------
# Source Sentence: je suis impressionne par votre francais EOS
# GT Sentence: i m impressed with your french EOS
# Predicted Sentence: i m impressed with your french EOS
#
# -----------------------------------
# Source Sentence: nous allons bien tous les deux EOS
# GT Sentence: we re both fine EOS
# Predicted Sentence: we re all all all EOS
#
# -----------------------------------
# Source Sentence: vous n etes pas normal EOS
# GT Sentence: you re not normal EOS
# Predicted Sentence: you re not normal EOS
#
# -----------------------------------
# Source Sentence: je plaisante EOS
# GT Sentence: i m just kidding EOS
# Predicted Sentence: i m joking EOS
#
# -----------------------------------
# Source Sentence: elles ne vont pas revenir EOS
# GT Sentence: they re not coming back EOS
# Predicted Sentence: they re not going back EOS
#
# -----------------------------------
# Source Sentence: nous sommes detendus EOS
# GT Sentence: we re relaxed EOS
# Predicted Sentence: we re shaken EOS
#
# -----------------------------------
# Source Sentence: je suis content d avoir autant de bons amis EOS
# GT Sentence: i am happy to have so many good friends EOS
# Predicted Sentence: i m very glad to see your much good EOS
#
# -----------------------------------
# Source Sentence: nous sommes les meilleurs EOS
# GT Sentence: we are the best EOS
# Predicted Sentence: we re the best EOS
#
# -----------------------------------
# Source Sentence: je suis fatigue de tous leurs mensonges EOS
# GT Sentence: i m fed up with all their lies EOS
# Predicted Sentence: i m tired of making a cold EOS
#
# -----------------------------------
# Source Sentence: elle n est pas plus belle que sa mere EOS
# GT Sentence: she s not prettier than her mother EOS
# Predicted Sentence: she is not as beautiful as her mother EOS
#
# -----------------------------------
# Source Sentence: nous ne sommes pas ici pour vous arreter EOS
# GT Sentence: we are not here to arrest you EOS
# Predicted Sentence: we re not here to help here EOS
#
# -----------------------------------
# Source Sentence: tu n es pas millionnaire EOS
# GT Sentence: you re not a millionaire EOS
# Predicted Sentence: you re not a millionaire EOS
#
# -----------------------------------
# Source Sentence: ils sont tous coupables EOS
# GT Sentence: they re all guilty EOS
# Predicted Sentence: they re all guilty EOS
#
# -----------------------------------
# Source Sentence: je crains qu il pleuve demain EOS
# GT Sentence: i m afraid it s going to rain tomorrow EOS
# Predicted Sentence: i m afraid it s going tomorrow EOS
#
# -----------------------------------
# Source Sentence: je suis content que ca te rende heureuse EOS
# GT Sentence: i m glad that makes you happy EOS
# Predicted Sentence: i m glad happy makes you happy EOS
#
# -----------------------------------
# Source Sentence: c est un pauvre type sans c ur EOS
# GT Sentence: he s a cold hearted jerk EOS
# Predicted Sentence: he s a very nice guy EOS
#
# -----------------------------------
# Source Sentence: vous restez avec tom n est ce pas ? EOS
# GT Sentence: you re staying with tom right ? EOS
# Predicted Sentence: you re talking to do tom EOS
#
# -----------------------------------
# Source Sentence: c est une jumelle EOS
# GT Sentence: she is a twin EOS
# Predicted Sentence: she s a wonderful EOS
#
# -----------------------------------
# Source Sentence: elle est toujours soigneusement habillee EOS
# GT Sentence: she is always neatly dressed EOS
# Predicted Sentence: she is always dressed dressed EOS
#
# -----------------------------------
# Source Sentence: nous vous protegeons EOS
# GT Sentence: we re protecting you EOS
# Predicted Sentence: you re waiting on you EOS
#
# -----------------------------------
# Source Sentence: je redoute l examen EOS
# GT Sentence: i m dreading the exam EOS
# Predicted Sentence: i m dreading the exam EOS
#
# -----------------------------------
# Source Sentence: je suis celibataire EOS
# GT Sentence: i m unmarried EOS
# Predicted Sentence: i m single EOS
#
# -----------------------------------
# Source Sentence: ils se sourient EOS
# GT Sentence: they re smiling at each other EOS
# Predicted Sentence: they re playing dinner EOS
#
# -----------------------------------
# Source Sentence: je vais a paris a l automne EOS
# GT Sentence: i m going to paris in the fall EOS
# Predicted Sentence: i m going to the phone of the class EOS
#
# -----------------------------------
# Source Sentence: je suis actuellement a l ecole EOS
# GT Sentence: i m at school now EOS
# Predicted Sentence: i am from from work worker EOS
#
# -----------------------------------
# Source Sentence: c est un magnat EOS
# GT Sentence: he s a tycoon EOS
# Predicted Sentence: he s a wonderful EOS
#
# -----------------------------------
# Source Sentence: vous n etes pas tres amusant EOS
# GT Sentence: you re not very funny EOS
# Predicted Sentence: you re not very funny EOS
#
# -----------------------------------
# Source Sentence: je suis desolee de t avoir crie apres EOS
# GT Sentence: i m sorry i yelled at you EOS
# Predicted Sentence: i m sorry i yelled at you EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas le patron EOS
# GT Sentence: i m not the manager EOS
# Predicted Sentence: i m not the boss EOS
#
# -----------------------------------
# Source Sentence: il n est pas japonais EOS
# GT Sentence: he is not japanese EOS
# Predicted Sentence: he is not japanese EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas stupide a ce point ! EOS
# GT Sentence: i m not that stupid ! EOS
# Predicted Sentence: i m not ready to do him EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas flic EOS
# GT Sentence: i m not a cop EOS
# Predicted Sentence: i m not a professional EOS
#
# -----------------------------------
# Source Sentence: nous ne sommes pas des tueurs EOS
# GT Sentence: we re not killers EOS
# Predicted Sentence: we re not short EOS
#
# -----------------------------------
# Source Sentence: ils sont de retour EOS
# GT Sentence: they re back EOS
# Predicted Sentence: they re back EOS
#
# -----------------------------------
# Source Sentence: tu as surement d autres talents EOS
# GT Sentence: i m sure you have other skills EOS
# Predicted Sentence: you re going to tell by i others EOS
#
# -----------------------------------
# Source Sentence: je suis comme ma mere EOS
# GT Sentence: i am like my mother EOS
# Predicted Sentence: i am still my my son EOS
#
# -----------------------------------
# Source Sentence: je suis fort modeste EOS
# GT Sentence: i m very modest EOS
# Predicted Sentence: i m very brave EOS
#
# -----------------------------------
# Source Sentence: je suis habitue a la situation EOS
# GT Sentence: i m familiar with the situation EOS
# Predicted Sentence: i am used to the subject EOS
#
# -----------------------------------
# Source Sentence: nous sommes inquiets pour leur securite EOS
# GT Sentence: we are anxious for their safety EOS
# Predicted Sentence: we re very grateful for you EOS
#
# -----------------------------------
# Source Sentence: tu es celle que j attendais EOS
# GT Sentence: you re the one i ve been waiting for EOS
# Predicted Sentence: you re the one one i can EOS
#
# -----------------------------------
# Source Sentence: vous etes tres elegants EOS
# GT Sentence: you re very stylish EOS
# Predicted Sentence: you re very stylish EOS
#
# -----------------------------------
# Source Sentence: vous n etes pas tres amusante EOS
# GT Sentence: you re not very funny EOS
# Predicted Sentence: you re not very funny EOS
#
# -----------------------------------
# Source Sentence: nous sommes en train de le reparer EOS
# GT Sentence: we re fixing it EOS
# Predicted Sentence: we re all the same EOS
#
# -----------------------------------
# Source Sentence: vous etes tous malades EOS
# GT Sentence: you re all insane EOS
# Predicted Sentence: you re all crazy EOS
#
# -----------------------------------
# Source Sentence: nous sommes plutot occupes ici EOS
# GT Sentence: we re kind of busy here EOS
# Predicted Sentence: we re too busy EOS
#
# -----------------------------------
# Source Sentence: elle apprend a conduire une voiture EOS
# GT Sentence: she is learning how to drive a car EOS
# Predicted Sentence: she is getting a car car EOS
#
# -----------------------------------
# Source Sentence: je ne suis pas un criminel EOS
# GT Sentence: i m not a criminal EOS
# Predicted Sentence: i m not a patient EOS
#
# -----------------------------------
# Source Sentence: je suis un peu sceptique EOS
# GT Sentence: i m a little skeptical EOS
# Predicted Sentence: i m a bit EOS
# -----------------------------------
# Eval Loss=2.0681
